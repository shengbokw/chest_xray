# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
from scipy.stats import norm, skew 
from scipy.special import boxcox1p

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# Load pneumonia_train data

# %%
pne_train = pd.read_csv('pneumonia_train_small.csv')

# %% [markdown]
# Add label for this dataframe

# %%
pne_train['label'] = 1

# %% [markdown]
# Do the same step for normal dataFrame

# %%
nor_train = pd.read_csv('normal_train_small.csv')
nor_train['label'] = 0

# %% [markdown]
# Concatenating the Pneumonia and Normal DataFrame into the whole train dataset

# %%
train = pd.concat([pne_train, nor_train], ignore_index=True)

# %% [markdown]
# Looking at the Summary for this train data set

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216 entries, 0 to 5215
# Data columns (total 22 columns):
# gray_0          5216 non-null int64
# gray_1          5216 non-null int64
# gray_2          5216 non-null int64
# gray_3          5216 non-null int64
# gray_4          5216 non-null int64
# gray_5          5216 non-null int64
# gray_6          5216 non-null int64
# gray_7          5216 non-null int64
# gray_8          5216 non-null int64
# gray_9          5216 non-null int64
# gray_10         5216 non-null int64
# gray_11         5216 non-null int64
# gray_12         5216 non-null int64
# gray_13         5216 non-null int64
# gray_14         5216 non-null int64
# gray_15         5216 non-null int64
# total_gray      5216 non-null int64
# lung_density    5216 non-null float64
# r_lungsize      5216 non-null int64
# l_lungsize      5216 non-null int64
# fraction        5213 non-null float64
# label           5216 non-null int64
# dtypes: float64(2), int64(20)
# ...

# %%
train.head()
# Out:
#    gray_0  gray_1  gray_2  gray_3  gray_4  gray_5  gray_6  gray_7  gray_8  \
# 0    4335    4313    4331    4344    4343    4415    4345    4355    4327
# 1    4127    4578    4353    4253    4311    4348    4288    4133    4240
# 2   13024    3709    3716    3742    3753    3722    3760    3730    3729
# 3    4344    4371    4291    4302    4365    4388    4388    4359    4375
# 4    4060    4591    4222    4409    4353    4374    4384    4442    4322
#
#    gray_9  ...    gray_12  gray_13  gray_14  gray_15  total_gray  \
# 0    4299  ...       4196     4264     4931        1      461946
# 1    4168  ...       4430     4686     4868        2      465175
# 2    3759  ...       3740     3772     3910        4      395468
# 3    4324  ...       4368     4365     4710        1      461305
# 4    4403  ...       4387     4250     4669        2      461485
#
#    lung_density  r_lungsize  l_lungsize  fraction  label
# 0      5.142837       12847        7966     0.620      1
# ...

# %%
train.describe()
# Out:
#              gray_0       gray_1       gray_2       gray_3       gray_4  \
# count   5216.000000  5216.000000  5216.000000  5216.000000  5216.000000
# mean    7270.976994  4137.356979  4122.493482  4128.902607  4138.408742
# std     3280.133602   322.467527   268.602584   236.024847   233.157563
# min     1418.000000   188.000000  2365.000000  2574.000000  2929.000000
# 25%     4366.000000  3941.750000  3953.000000  3968.000000  3974.750000
# 50%     6157.500000  4166.000000  4181.000000  4199.000000  4212.000000
# 75%     9622.500000  4313.000000  4304.000000  4319.000000  4332.000000
# max    24349.000000  9053.000000  8180.000000  5218.000000  4653.000000
#
#             gray_5       gray_6       gray_7       gray_8       gray_9  \
# count  5216.000000  5216.000000  5216.000000  5216.000000  5216.000000
# mean   4143.204755  4143.588190  4141.949578  4136.968558  4128.828604
# std     234.022016   235.246174   235.011811   235.174621   233.570922
# ...

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=1, square=True);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# From the Correlation coefficient matrix, We see that for lable, the most positive correlated features are lung_density, gray_14, the most negitive correlated features are gray_0, gray_15, l_lungsize and fraction.

# %%
k = 7
cols = corrmat.nlargest(k, 'label')['label'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
yticklabels=cols.values, xticklabels=cols.values)
plt.show();

# %%
sns.set()
cols = ['label','gray_14','lung_density','total_gray','gray_6','gray_7','gray_5']
sns.pairplot(train[cols], size = 2.5)
plt.show();
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
